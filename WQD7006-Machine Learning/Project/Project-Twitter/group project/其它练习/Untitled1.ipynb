# %%
import pandas as pd

df=pd.read_csv("label_tweets_v2.csv")
df.head()
# Out:
#    Unnamed: 0   score  label  \
# 0           0 -0.0258    0.0
# 1           1  0.0000    NaN
# 2           2  0.1779    1.0
# 3           3  0.5719    1.0
# 4           4  0.9349    1.0
#
#                                                 text             date  \
# 0  yes you can get burnout stress migraines even ...  4/29/2020 23:59
# 1  it s am so i should probably change from my pj...  4/29/2020 23:59
# 2  icymi an rsa customer and discuss how the incr...  4/29/2020 23:59
# 3  my shift has ended hurray for the long weekend...  4/29/2020 23:59
# 4  who can share the best hr policy for wfh in my...  4/29/2020 23:59
#
#        username                                     hashtags
# 0  maria_emlano                                         #WFH
# 1   DrHelen_Mac                          #IsolationLife #WFH
# 2   RSAsecurity  #ICYMI #WFH #security #DynamicWorkforceRisk
# 3  iam_aikenlei                    #wfh #longweekend #ecqpic
# ...
