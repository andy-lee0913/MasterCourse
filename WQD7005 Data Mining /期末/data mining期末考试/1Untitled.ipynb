# %%
# data crawling

import requests
import pandas as pd
from bs4 import BeautifulSoup

headers={
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'
}


url = "https://www.indexmundi.com/commodities/?commodity=petroleum-price-index&months=360"

res = requests.get(url,headers=headers)

try:

    df = pd.read_html(res.text)
    pan = pd.DataFrame(df[1])
    data = {'Month':pan.iloc[:,0],'Price':pan.iloc[:,1],'Change':pan.iloc[:,2]}
    df = pd.DataFrame(data=data)
except:
    print("The url doesn't work!")

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

headers={
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'
}


url = "https://www.indexmundi.com/commodities/?commodity=petroleum-price-index&months=360"

res = requests.get(url,headers=headers)






try:

    df = pd.read_html(res.text)
    pan = pd.DataFrame(df[1])

#     d={'Year':pan.iloc[:,0],'AverageClosing Price':pan.iloc[:,1],'Year Open':pan.iloc[:,2],'Year High':pan.iloc[:,3],'Year Low':pan.iloc[:,4],'Year Close':pan.iloc[:,5],'Annual% Change':pan.iloc[:,6]}
#     df = pd.DataFrame(data=d)
#     df.to_csv('oilCrawl.csv')
except:

    print("The url doesn't work!")

# %%
data = {'Month':pan.iloc[:,0],'Price':pan.iloc[:,1],'Change':pan.iloc[:,2]}

# %%
df = pd.DataFrame(data=data)

# %%
df.head()
# Out:
#       Month  Price  Change
# 0  Jan 1992  40.23       -
# 1  Feb 1992  41.09  2.14 %
# 2  Mar 1992  41.17  0.19 %
# 3  Apr 1992  44.09  7.09 %
# 4  May 1992  45.57  3.36 %

# %%
# data = {'Month':pan.iloc[:,0],'Price':pan.iloc[:1],'Change':pan.iloc[:2]}
# pan.iloc[:,2]
# df = pd.DataFrame(data=data)
# df.head()
# Out:
# 0             -
# 1        2.14 %
# 2        0.19 %
# 3        7.09 %
# 4        3.36 %
# 5        5.16 %
# 6       -5.45 %
# 7       -3.66 %
# 8        2.84 %
# 9        0.82 %
# 10      -2.45 %
# 11      -5.25 %
# 12      -3.06 %
# 13       6.14 %
# 14       0.88 %
# 15      -2.60 %
# 16      -1.73 %
# 17      -3.97 %
# 18      -4.43 %
# 19      -0.45 %
# 20      -4.90 %
# 21       4.76 %
# 22      -7.01 %
# 23     -11.06 %
# 24       6.87 %
# 25      -3.95 %
# 26      -1.49 %
# 27      10.52 %
# 28       7.64 %
# 29       3.99 %
#          ...
# 310      9.27 %
# 311      1.59 %
# 312      6.33 %
# 313     -4.97 %
# 314      1.08 %
# 315      7.34 %
# 316      8.59 %
# 317     -1.10 %
# 318      1.62 %
# 319     -1.57 %
# 320      5.68 %
# 321      2.52 %
# 322    -18.30 %
# 323    -13.82 %
# 324      4.24 %
# 325      8.45 %
# 326      4.44 %
# 327      7.79 %
# 328     -2.08 %
# 329    -10.95 %
# 330      3.24 %
# 331     -5.73 %
# 332      4.52 %
# 333     -4.76 %
# 334      5.20 %
# 335      4.64 %
# 336     -2.73 %
# 337    -12.82 %
# 338    -39.76 %
# 339    -33.81 %
# Name: Change, Length: 340, dtype: object

# %%
len(list)
# Out:
# 2

# %%
list[1]
# Out:
#         Month   Price    Change
# 0    Jan 1992   40.23         -
# 1    Feb 1992   41.09    2.14 %
# 2    Mar 1992   41.17    0.19 %
# 3    Apr 1992   44.09    7.09 %
# 4    May 1992   45.57    3.36 %
# 5    Jun 1992   47.92    5.16 %
# 6    Jul 1992   45.31   -5.45 %
# 7    Aug 1992   43.65   -3.66 %
# 8    Sep 1992   44.89    2.84 %
# 9    Oct 1992   45.26    0.82 %
# 10   Nov 1992   44.15   -2.45 %
# 11   Dec 1992   41.83   -5.25 %
# 12   Jan 1993   40.55   -3.06 %
# 13   Feb 1993   43.04    6.14 %
# 14   Mar 1993   43.42    0.88 %
# 15   Apr 1993   42.29   -2.60 %
# 16   May 1993   41.56   -1.73 %
# 17   Jun 1993   39.91   -3.97 %
# 18   Jul 1993   38.14   -4.43 %
# 19   Aug 1993   37.97   -0.45 %
# 20   Sep 1993   36.11   -4.90 %
# 21   Oct 1993   37.83    4.76 %
# 22   Nov 1993   35.18   -7.01 %
# 23   Dec 1993   31.29  -11.06 %
# 24   Jan 1994   33.44    6.87 %
# 25   Feb 1994   32.12   -3.95 %
# 26   Mar 1994   31.64   -1.49 %
# 27   Apr 1994   34.97   10.52 %
# 28   May 1994   37.64    7.64 %
# 29   Jun 1994   39.14    3.99 %
# ..        ...     ...       ...
# 310  Nov 2017  138.15    9.27 %
# 311  Dec 2017  140.34    1.59 %
# 312  Jan 2018  149.22    6.33 %
# 313  Feb 2018  141.81   -4.97 %
# 314  Mar 2018  143.34    1.08 %
# 315  Apr 2018  153.86    7.34 %
# 316  May 2018  167.08    8.59 %
# 317  Jun 2018  165.24   -1.10 %
# 318  Jul 2018  167.92    1.62 %
# 319  Aug 2018  165.28   -1.57 %
# 320  Sep 2018  174.66    5.68 %
# 321  Oct 2018  179.06    2.52 %
# 322  Nov 2018  146.29  -18.30 %
# 323  Dec 2018  126.08  -13.82 %
# 324  Jan 2019  131.42    4.24 %
# 325  Feb 2019  142.53    8.45 %
# 326  Mar 2019  148.86    4.44 %
# 327  Apr 2019  160.45    7.79 %
# 328  May 2019  157.12   -2.08 %
# 329  Jun 2019  139.92  -10.95 %
# 330  Jul 2019  144.45    3.24 %
# 331  Aug 2019  136.17   -5.73 %
# 332  Sep 2019  142.33    4.52 %
# 333  Oct 2019  135.55   -4.76 %
# 334  Nov 2019  142.60    5.20 %
# 335  Dec 2019  149.22    4.64 %
# 336  Jan 2020  145.14   -2.73 %
# 337  Feb 2020  126.53  -12.82 %
# 338  Mar 2020   76.22  -39.76 %
# 339  Apr 2020   50.45  -33.81 %
#
# [340 rows x 3 columns]

# %%
import requests

from bs4 import BeautifulSoup

import pandas as pd
url = "https://www.indexmundi.com/commodities/"

resp = requests.get(url)

list = pd.read_html(resp.text)

# %%
len(list)
# Out:
# 2

# %%
list[0]
# Out:
#                                                    0
# 0  Commodity Prices  Click on a commodity from th...

# %%
list[1]
# Out:
#                                          Commodity 1 Month Change  \
# 0       Commodity Agricultural Raw Materials Index        -2.01 %
# 1                   Commodity Beverage Price Index        -0.14 %
# 2                            Commodity Price Index       -10.34 %
# 3                    Commodity Fuel (energy) Index       -30.19 %
# 4          Commodity Food and Beverage Price Index        -4.08 %
# 5                       Commodity Food Price Index        -2.75 %
# 6          Commodity Industrial Inputs Price Index        -4.12 %
# 7                     Commodity Metals Price Index        -4.59 %
# 8                   Commodity Non-Fuel Price Index        -2.82 %
# 9               Crude Oil (petroleum), Price index       -33.81 %
# 10                   Coal, Australian thermal coal       -12.27 %
# 11                Coal, South African export price       -16.66 %
# 12                           Crude Oil (petroleum)       -34.66 %
# 13              Crude Oil (petroleum); Dated Brent       -29.23 %
# 14              Crude Oil (petroleum); Dubai Fateh       -31.05 %
# 15  Crude Oil (petroleum); West Texas Intermediate       -44.71 %
# 16                                          Diesel       -26.05 %
# 17                                        Gasoline       -33.45 %
# 18                                     Heating Oil       -26.30 %
# 19                Indonesian Liquified Natural Gas         0.00 %
# 20                                        Jet Fuel       -36.41 %
# 21                                     Natural Gas        -2.79 %
# 22                                         Propane        11.99 %
# 23                                   RBOB Gasoline       -49.57 %
# 24                             Russian Natural Gas       -22.06 %
# 25                                     Cocoa beans        -2.99 %
# 26                     Coffee, Other Mild Arabicas         4.28 %
# 27                                 Coffee, Robusta        -5.37 %
# 28                                             Tea         5.53 %
# 29                                          Barley         0.00 %
# ..                                             ...            ...
# 60                                           Copra            NaN
# 61                                          Cotton        -6.04 %
# 62                                       Fine Wool            NaN
# 63                                       Hard Logs        -0.25 %
# 64                                   Hard Sawnwood            NaN
# 65                                           Hides            NaN
# 66                                         Plywood        -0.25 %
# 67                                          Rubber       -11.33 %
# 68                                       Soft Logs            NaN
# 69                                   Soft Sawnwood            NaN
# 70                                       Wood Pulp            NaN
# 71                                        Aluminum        -9.37 %
# 72                               Cold-rolled steel            NaN
# 73                         Copper, grade A cathode        -2.41 %
# 74                                            Gold         5.73 %
# 75                                Hot-rolled steel            NaN
# 76                                        Iron Ore        -4.79 %
# 77                                            Lead        -4.43 %
# 78                                          Nickel        -0.36 %
# 79                                           Rebar            NaN
# 80                                          Silver         1.28 %
# 81                                  Steel wire rod            NaN
# 82                                             Tin        -2.21 %
# 83                                         Uranium            NaN
# 84                                            Zinc        -0.01 %
# 85                                  DAP fertilizer         2.09 %
# 86                              Potassium Chloride         0.00 %
# 87                                  Rock Phosphate        -1.57 %
# 88                           Triple Superphosphate         0.00 %
# 89                                            Urea         1.67 %
#
#    12 Month Change Year to Date Change
# 0          -7.84 %             -5.97 %
# 1           1.99 %             -5.44 %
# 2         -31.81 %            -29.60 %
# 3         -65.11 %            -60.54 %
# 4          -7.04 %            -10.70 %
# 5          -0.40 %             -8.80 %
# 6         -16.27 %            -12.79 %
# 7         -19.67 %            -15.64 %
# 8          -7.88 %             -9.70 %
# 9         -68.56 %            -65.24 %
# 10        -32.52 %            -15.95 %
# 11        -21.95 %            -31.08 %
# 12        -69.32 %            -65.86 %
# 13        -67.22 %            -63.30 %
# 14        -67.07 %            -63.50 %
# 15        -74.13 %            -71.28 %
# 16        -57.32 %            -52.59 %
# 17        -70.96 %            -64.34 %
# 18        -58.15 %            -53.62 %
# 19         -0.58 %              3.24 %
# 20        -69.35 %            -65.90 %
# 21        -34.34 %            -14.29 %
# 22        -49.07 %            -23.78 %
# 23        -81.33 %            -74.57 %
# 24        -56.91 %            -41.60 %
# 25         -2.58 %            -12.69 %
# 26         27.72 %              8.95 %
# 27        -12.96 %             -9.62 %
# 28         -7.08 %             -8.30 %
# 29        -15.83 %              0.00 %
# ..             ...                 ...
# 60             NaN                 NaN
# 61        -27.08 %            -19.54 %
# 62             NaN                 NaN
# 63          3.59 %              1.41 %
# 64             NaN                 NaN
# 65             NaN                 NaN
# 66          3.59 %              1.41 %
# 67        -22.67 %            -20.83 %
# 68             NaN                 NaN
# 69             NaN                 NaN
# 70             NaN                 NaN
# 71        -20.89 %            -17.66 %
# 72             NaN                 NaN
# 73        -21.44 %            -16.14 %
# 74         30.89 %              7.85 %
# 75             NaN                 NaN
# 76         -9.57 %            -11.52 %
# 77        -14.51 %            -13.85 %
# 78         -7.58 %            -12.61 %
# 79             NaN                 NaN
# 80          0.07 %            -16.14 %
# 81             NaN                 NaN
# 82        -27.43 %            -12.19 %
# 83             NaN                 NaN
# 84        -35.10 %            -19.15 %
# 85        -12.90 %              6.46 %
# 86         -7.72 %              0.00 %
# 87        -27.44 %             -2.41 %
# 88        -20.97 %              2.51 %
# 89         -5.05 %              9.10 %
#
# [90 rows x 4 columns]

# %%
import requests

from bs4 import BeautifulSoup

import pandas as pd
url = "https://www.indexmundi.com/commodities/?commodity=commodity-price-index&months=360"

resp = requests.get(url)

list = pd.read_html(resp.text)

# %%
len(list)
# Out:
# 2

# %%
list[1]
# Out:
#         Month   Price    Change
# 0    Jan 1992   50.72         -
# 1    Feb 1992   50.72    0.00 %
# 2    Mar 1992   50.75    0.06 %
# 3    Apr 1992   51.17    0.83 %
# 4    May 1992   52.64    2.87 %
# 5    Jun 1992   52.85    0.40 %
# 6    Jul 1992   52.52   -0.62 %
# 7    Aug 1992   52.58    0.11 %
# 8    Sep 1992   53.01    0.82 %
# 9    Oct 1992   52.50   -0.96 %
# 10   Nov 1992   50.37   -4.06 %
# 11   Dec 1992   50.41    0.08 %
# 12   Jan 1993   49.83   -1.15 %
# 13   Feb 1993   50.35    1.04 %
# 14   Mar 1993   51.75    2.78 %
# 15   Apr 1993   52.01    0.50 %
# 16   May 1993   52.12    0.21 %
# 17   Jun 1993   50.70   -2.72 %
# 18   Jul 1993   50.61   -0.18 %
# 19   Aug 1993   50.43   -0.36 %
# 20   Sep 1993   49.47   -1.90 %
# 21   Oct 1993   49.52    0.10 %
# 22   Nov 1993   48.81   -1.43 %
# 23   Dec 1993   49.08    0.55 %
# 24   Jan 1994   49.87    1.61 %
# 25   Feb 1994   50.69    1.64 %
# 26   Mar 1994   50.30   -0.77 %
# 27   Apr 1994   50.99    1.37 %
# 28   May 1994   52.40    2.77 %
# 29   Jun 1994   53.31    1.74 %
# ..        ...     ...       ...
# 310  Nov 2017  120.83    4.09 %
# 311  Dec 2017  122.54    1.42 %
# 312  Jan 2018  129.83    5.95 %
# 313  Feb 2018  127.00   -2.18 %
# 314  Mar 2018  126.58   -0.33 %
# 315  Apr 2018  128.54    1.55 %
# 316  May 2018  133.35    3.74 %
# 317  Jun 2018  132.22   -0.85 %
# 318  Jul 2018  130.47   -1.32 %
# 319  Aug 2018  128.26   -1.69 %
# 320  Sep 2018  132.70    3.46 %
# 321  Oct 2018  133.71    0.76 %
# 322  Nov 2018  122.16   -8.64 %
# 323  Dec 2018  116.15   -4.92 %
# 324  Jan 2019  117.08    0.80 %
# 325  Feb 2019  119.01    1.65 %
# 326  Mar 2019  119.91    0.76 %
# 327  Apr 2019  123.42    2.93 %
# 328  May 2019  120.48   -2.38 %
# 329  Jun 2019  115.53   -4.11 %
# 330  Jul 2019  117.97    2.11 %
# 331  Aug 2019  112.71   -4.46 %
# 332  Sep 2019  114.81    1.86 %
# 333  Oct 2019  113.02   -1.56 %
# 334  Nov 2019  116.91    3.44 %
# 335  Dec 2019  119.91    2.57 %
# 336  Jan 2020  119.55   -0.30 %
# 337  Feb 2020  111.09   -7.08 %
# 338  Mar 2020   93.87  -15.50 %
# 339  Apr 2020   84.16  -10.34 %
#
# [340 rows x 3 columns]
