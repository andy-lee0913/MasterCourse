# %%
import pandas as pd
df = pd.DataFrame({'Yes':[2,3],'No':[5,6]})

# %%
df=pd.read_csv('ufo.csv')

# %%
df.shape
# Out:
# (18241, 5)

# %%
df.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
df.dropna(how='any').shape
# Out:
# (2486, 5)

# %%
df.dropna(subset=['City','Colors Reported'],how='all').shape
# Out:
# (18221, 5)

# %%
df['Colors Reported'].fillna(value='Red',inplace=True)

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             Red       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             Red          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             Red           OVAL    CO  2/15/1931 14:00
# 3               Abilene             Red           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             Red          LIGHT    NY  4/18/1933 19:00

# %%
df["Shape Reported"].fillna( method ='ffill',inplace = True)

# %%
df.isnull().sum()
# Out:
# City               25
# Colors Reported     0
# Shape Reported      0
# State               0
# Time                0
# dtype: int64

# %%
df['Colors Reported']=df['Colors Reported'].replace(to_replace ="Red", 
                 value ="Omega")

# %%
df.interpolate(method='values',limit_direction ='forward')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-f5dbef6d7380> in <module>
# ----> 1 df.interpolate(method='values',limit_direction ='forward')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6812         if _maybe_transposed_self._data.get_dtype_counts().get(
#    6813                 'object') == len(_maybe_transposed_self.T):
# -> 6814             raise TypeError("Cannot interpolate with all object-dtype columns "
#    6815                             "in the DataFrame. Try setting at least one "
#    6816                             "column to a numeric dtype.")
#
# TypeError: Cannot interpolate with all object-dtype columns in the DataFrame. Try setting at least one column to a numeric dtype.

# %%
df2 = pd.DataFrame({"A":[12, 4, 5, None, 1], 
                   "B":[None, 2, 54, 3, None], 
                   "C":[20, 16, None, 3, 8], 
                   "D":[14, 3, None, None, 6]})

# %%
df2
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %%
df2.interpolate(method='values',limit_direction ='both')
# Out:
#       A     B     C     D
# 0  12.0   2.0  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   9.5   4.0
# 3   3.0   3.0   3.0   5.0
# 4   1.0   3.0   8.0   6.0

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df.columns.str.upper()
# Out:
# Index(['CITY', 'COLORS REPORTED', 'SHAPE REPORTED', 'STATE', 'TIME'], dtype='object')

# %%
df.fillna(0)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca               0       TRIANGLE    NY
# 1               Willingboro               0          OTHER    NJ
# 2                   Holyoke               0           OVAL    CO
# 3                   Abilene               0           DISK    KS
# 4      New York Worlds Fair               0          LIGHT    NY
# 5               Valley City               0           DISK    ND
# 6               Crater Lake               0         CIRCLE    CA
# 7                      Alma               0           DISK    MI
# 8                   Eklutna               0          CIGAR    AK
# 9                   Hubbard               0       CYLINDER    OR
# 10                  Fontana               0          LIGHT    CA
# 11                 Waterloo               0       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# 13                   Keokuk               0           OVAL    IA
# 14                Ludington               0           DISK    MI
# 15              Forest Home               0         CIRCLE    CA
# 16              Los Angeles               0              0    CA
# 17                Hapeville               0              0    GA
# 18                   Oneida               0      RECTANGLE    TN
# 19               Bering Sea             RED          OTHER    AK
# 20                 Nebraska               0           DISK    NE
# 21                        0               0              0    LA
# 22                        0               0          LIGHT    LA
# 23                Owensboro               0      RECTANGLE    KY
# 24               Wilderness               0           DISK    WV
# 25                San Diego               0          CIGAR    CA
# 26               Wilderness               0           DISK    WV
# 27                   Clovis               0           DISK    NM
# 28               Los Alamos               0           DISK    NM
# 29             Ft. Duschene               0           DISK    UT
# ...                     ...             ...            ...   ...
# 18211               Holyoke               0        DIAMOND    MA
# 18212                Carson               0           DISK    CA
# 18213              Pasadena           GREEN       FIREBALL    CA
# 18214                Austin               0      FORMATION    TX
# 18215              El Campo               0          OTHER    TX
# 18216          Garden Grove          ORANGE          LIGHT    CA
# 18217         Berthoud Pass               0       TRIANGLE    CO
# 18218            Sisterdale               0        DIAMOND    TX
# 18219          Garden Grove               0        CHEVRON    CA
# 18220           Shasta Lake            BLUE           DISK    CA
# 18221              Franklin               0           DISK    NH
# 18222        Albrightsville               0          OTHER    PA
# 18223            Greenville               0              0    SC
# 18224               Eufaula               0           DISK    OK
# 18225           Simi Valley               0      FORMATION    CA
# 18226         San Francisco               0      FORMATION    CA
# 18227         San Francisco               0       TRIANGLE    CA
# 18228            Kingsville               0          LIGHT    TX
# 18229               Chicago               0           DISK    IL
# 18230           Pismo Beach               0           OVAL    CA
# 18231           Pismo Beach               0           OVAL    CA
# 18232                  Lodi               0              0    WI
# 18233             Anchorage             RED        VARIOUS    AK
# 18234              Capitola               0       TRIANGLE    CA
# 18235        Fountain Hills               0              0    AZ
# 18236            Grant Park               0       TRIANGLE    IL
# 18237           Spirit Lake               0           DISK    IA
# 18238           Eagle River               0              0    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor               0           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# 5       9/15/1934 15:30
# 6        6/15/1935 0:00
# 7        7/15/1936 0:00
# 8      10/15/1936 17:00
# 9        6/15/1937 0:00
# 10      8/15/1937 21:00
# 11       6/1/1939 20:00
# 12      6/30/1939 20:00
# 13        7/7/1939 2:00
# 14       6/1/1941 13:00
# 15       7/2/1941 11:30
# 16       2/25/1942 0:00
# 17       6/1/1942 22:30
# 18       7/15/1942 1:00
# 19      4/30/1943 23:00
# 20       6/1/1943 15:00
# 21       8/15/1943 0:00
# 22       8/15/1943 0:00
# 23     10/15/1943 11:00
# 24       1/1/1944 10:00
# 25       1/1/1944 12:00
# 26       1/1/1944 12:00
# 27       4/2/1944 11:00
# 28       6/1/1944 12:00
# 29      6/30/1944 10:00
# ...                 ...
# 18211  12/28/2000 18:00
# 18212  12/28/2000 18:20
# 18213  12/28/2000 19:10
# 18214   12/29/2000 0:00
# 18215   12/29/2000 9:00
# 18216  12/29/2000 16:10
# 18217  12/29/2000 19:30
# 18218  12/29/2000 20:00
# 18219  12/29/2000 20:30
# 18220  12/29/2000 20:30
# 18221  12/29/2000 20:50
# 18222  12/29/2000 21:00
# 18223  12/29/2000 22:00
# 18224  12/29/2000 23:30
# 18225  12/30/2000 10:00
# 18226  12/30/2000 22:00
# 18227  12/30/2000 22:00
# 18228   12/31/2000 4:00
# 18229  12/31/2000 11:45
# 18230  12/31/2000 20:00
# 18231  12/31/2000 20:00
# 18232  12/31/2000 20:30
# 18233  12/31/2000 21:00
# 18234  12/31/2000 22:00
# 18235  12/31/2000 23:00
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18239  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
df2.fillna(df2['B'].mean())
# Out:
#            A          B          C          D
# 0  12.000000  19.666667  20.000000  14.000000
# 1   4.000000   2.000000  16.000000   3.000000
# 2   5.000000  54.000000  19.666667  19.666667
# 3  19.666667   3.000000   3.000000  19.666667
# 4   1.000000  19.666667   8.000000   6.000000

# %%
# ?df2.dropna

# %%
df.loc[df.duplicated(),:].shape
# Out:
# (109, 5)

# %%
df.drop_duplicates(subset=['City','Colors Reported','Shape Reported']).shape
# Out:
# (14193, 5)

# %%
df.shape
# Out:
# (18241, 5)

# %%
df=pd.read_csv('ufo.csv',dtype={'City':str})

# %%
df.shape
# Out:
# (18241, 5)

# %%
df.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
df.City.astype(object).dtypes
# Out:
# dtype('O')

# %%
from sklearn import preprocessing
names = df2.columns
preprocessing.minmax_scale(df2,feature_range=(-1,1))
# Out:
# array([[ 1.        ,         nan,  1.        ,  1.        ],
#        [-0.45454545, -1.        ,  0.52941176, -1.        ],
#        [-0.27272727,  1.        ,         nan,         nan],
#        [        nan, -0.96153846, -1.        ,         nan],
#        [-1.        ,         nan, -0.41176471, -0.45454545]])

# %%
df2
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %%
names = df2.columns
scaler = preprocessing.StandardScaler()
df3=scaler.fit_transform(df2)
scaled_df = pd.DataFrame(df3,columns=names)
scaled_df
# Out:
#           A         B         C         D
# 0  1.612452       NaN  1.241093  1.364121
# 1 -0.372104 -0.727599  0.639351 -1.005141
# 2 -0.124035  1.414014       NaN       NaN
# 3       NaN -0.686414 -1.316310       NaN
# 4 -1.116313       NaN -0.564133 -0.358979

# %%
df4 = preprocessing.scale(df2)
scaled_df2 = pd.DataFrame(df4,columns=names)
scaled_df2
# Out:
#           A         B         C         D
# 0  1.612452       NaN  1.241093  1.364121
# 1 -0.372104 -0.727599  0.639351 -1.005141
# 2 -0.124035  1.414014       NaN       NaN
# 3       NaN -0.686414 -1.316310       NaN
# 4 -1.116313       NaN -0.564133 -0.358979
